# %% [markdown]
# #### *Create Dataset*

# %%
import pandas as pd 
import numpy as np
df = pd.DataFrame({
    'Age':[25, 30, np.nan, 35, 40],
    'Salary':[30000, 40000, 50000, np.nan, 70000],
    'Gender':['Male', 'Female', 'Male', 'Female', 'Male']
})
print(df)
# Out:
#     Age   Salary  Gender
# 0  25.0  30000.0    Male
# 1  30.0  40000.0  Female
# 2   NaN  50000.0    Male
# 3  35.0      NaN  Female
# 4  40.0  70000.0    Male

# %% [markdown]
# #### *Handling in Missing values*

# %%
df['Age'] = df['Age'].fillna(df['Age'].mode()[0])
df['Salary'] =df['Salary'].fillna(df['Salary'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Age       0
# Salary    0
# Gender    0
# dtype: int64

# %%
print(df)
# Out:
#     Age   Salary  Gender
# 0  25.0  30000.0    Male
# 1  30.0  40000.0  Female
# 2  25.0  50000.0    Male
# 3  35.0  30000.0  Female
# 4  40.0  70000.0    Male

# %% [markdown]
# #### *Encoding Gender*

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
print(df)
# Out:
#     Age   Salary  Gender
# 0  25.0  30000.0       1
# 1  30.0  40000.0       0
# 2  25.0  50000.0       1
# 3  35.0  30000.0       0
# 4  40.0  70000.0       1

# %% [markdown]
# #### *Scale Age and Salary*

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Age', 'Salary']] = scaler.fit_transform(
    df[['Age', 'Salary']]
)
print(df)
# Out:
#         Age    Salary  Gender
# 0 -1.028992 -0.935414       1
# 1 -0.171499 -0.267261       0
# 2 -1.028992  0.400892       1
# 3  0.685994 -0.935414       0
# 4  1.543487  1.737198       1

# %% [markdown]
# #### *Saved cleaned dataset*

# %%
df.to_csv('cleaned_employee_data.csv', index=False)
print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %% [markdown]
# ## conclusion

# %% [markdown]
# #####  In this project, I:
# ##### - Handled missing values using mod.
# ##### - Encoded categoriocal data using LabelEncoder.
# ##### - Scaled numerical features using StandardScaler.
# ##### - Saved the cleaned dataset for machine learning .
